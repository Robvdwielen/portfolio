# %% [markdown]
# # THRIFT IT LIKE MACKLEMORE @ ZALANDO

# %% [markdown]
# This webscraper contains two parts: the web scraper for Zalando's Pre-owned men's clothing section and the web scraper for Zalando's Regular men's clothing section. The purpose of these web scrapers is to gather information about the products and to determine the difference between the offerings of the Pre-owned and the Regular Zalando web pages based on brands, product categories and prices. The feasible sample size contains 214 pages for both men's clothing sections and 18190 products for Zalando's Pre-owned men's clothing section and 18190 products for Zalando's Regular men's clothing section.
#
# NOTE: The class names used to extract the data might have been changed due to new updates to the Zalando website.

# %% [markdown]
# **Import packages & run Selenium**
# Selenium is used to scrape the product information of the Zalando pages as the products on the web pages load when scrolling down the page. However, it is not possible to manually scroll down the pages when web scraping the website.

# %%
from bs4 import BeautifulSoup
import requests
import time 
from time import sleep
from datetime import datetime
import csv

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from re import search
from selenium.webdriver import ActionChains

# %%
# debug = {'verbose': sys.stderr}
user_agent = {'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36 Edg/98.0.1108.62'}

# %% [markdown]
# ## Chapter 1: Zalando scraper | Pre-owned Heren
# This part of the web scraper contains code to scrape the Zalando web page(s) of the Zalando Pre-owned Men's clothing section (https://zalando.nl/pre-owned-mode-heren/index.html). From now on, the variable names end with 'po' as an indication to the Pre-owned label.

# %% [markdown]
# ### 1.1 Run Chromedriver

# %%
# use webdriver.Chrome()
driver_po = webdriver.Chrome(ChromeDriverManager().install())

# run Zalando Pre-owned 
driver_po.get("https://www.zalando.nl/pre-owned-mode-heren/")
time.sleep(10)
print("done")
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Systeembeheer\.wdm\drivers\chromedriver\win32\99.0.4844.51]
# done

# %% [markdown]
# ### 1.2 Automatic acceptation of cookies
# The cookies are automatically accepted to close pop-ups before proceeding with web scraping.

# %%
driver_po.find_element_by_id("uc-btn-accept-banner").click()

# %% [markdown]
# ### 1.3 Collect page urls

# %%
base_url_po = "https://www.zalando.nl/pre-owned-mode-heren/?p="
counter_po = 1

def generate_page_urls_po(base_url_po, num_pages_po):
    page_urls_po = []
    
    for counter_po in range (1, num_pages_po + 1):
        full_url_po = base_url_po + str(counter_po) + "&order=activation_date"
        page_urls_po.append(full_url_po)
    
    return page_urls_po

# %%
page_urls_po = generate_page_urls_po(base_url_po, 1) 

# check and generate a subsample of 20 url's
generate_page_urls_po("https://www.zalando.nl/pre-owned-mode-heren/?p=", 20)
# Out:
# ['https://www.zalando.nl/pre-owned-mode-heren/?p=1&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=2&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=3&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=4&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=5&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=6&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=7&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=8&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=9&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=10&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=11&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=12&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=13&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=14&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=15&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=16&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=17&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=18&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=19&order=activation_date',
#  'https://www.zalando.nl/pre-owned-mode-heren/?p=20&order=activation_date']

# %% [markdown]
# ### 1.4 Collect product urls

# %%
def create_product_urls_po(page_urls_po):
    product_urls_po = []
    cnt=1
    for page_url_po in page_urls_po:
        cnt+=1
        driver_po.get(page_url_po)
        time.sleep(5)
        res_po = driver_po.page_source.encode('utf-8')
        soup_po = BeautifulSoup(res_po, "html.parser")
        products_po = soup_po.find_all("div", class_= "DT5BTM w8MdNG cYylcv QylWsg _75qWlu iOzucJ JT3_zV DvypSJ") 
        print(len(products_po))
        sleep(1)

        for product_po in products_po:
            try:
                product_url_po = product_po.find("a").attrs["href"]
                print(product_url_po)
                product_urls_po.append(product_url_po)
            except:
                print("dit is geen product")
                
    return product_urls_po

# %%
product_urls_po = create_product_urls_po(page_urls_po)
# Out:
# 84
# https://www.zalando.nl/oakley-overhemd-blue-zir01u72p-001.html
# https://www.zalando.nl/tom-tailor-overhemd-grey-zir00q0hu-001.html
# https://www.zalando.nl/polo-ralph-lauren-overhemd-blue-zir00nb0p-001.html
# https://www.zalando.nl/lauren-ralph-lauren-overhemd-blue-zir00q54e-001.html
# https://www.zalando.nl/polo-ralph-lauren-overhemd-blue-zir00n9x9-001.html
# https://www.zalando.nl/ted-baker-overhemd-blue-zir00q544-001.html
# https://www.zalando.nl/levis-overhemd-blue-zir00ptv5-001.html
# https://www.zalando.nl/levis-overhemd-blue-zir00ptpx-001.html
# https://www.zalando.nl/paul-smith-overhemd-taupe-zir01ub9d-001.html
# https://www.zalando.nl/eterna-overhemd-green-zir01u48a-001.html
# https://www.zalando.nl/qs-by-soliver-t-shirt-print-grey-zir016qsk-001.html
# https://www.zalando.nl/daniel-hechter-zakelijk-overhemd-brown-zir00ue0x-001.html
# https://www.zalando.nl/eterna-zakelijk-overhemd-white-zir01uj8d-001.html
# https://www.zalando.nl/scotch-and-soda-overhemd-green-zir01ujr1-001.html
# https://www.zalando.nl/soliver-selection-overhemd-blue-zir00q0bb-001.html
# https://www.zalando.nl/hollister-co-overhemd-blue-zir01u9y4-001.html
# https://www.zalando.nl/samsoee-samsoee-overhemd-blue-zir01u4xy-001.html
# https://www.zalando.nl/marks-and-spencer-london-overhemd-blue-zir00q51c-001.html
# https://www.zalando.nl/burton-overhemd-black-zir00q5j3-001.html
# https://www.zalando.nl/tommy-hilfiger-overhemd-white-zir00q9tk-001.html
# https://www.zalando.nl/next-overhemd-beige-zir00q63e-001.html
# https://www.zalando.nl/gap-overhemd-green-zir00q5gg-001.html
# https://www.zalando.nl/van-laack-overhemd-pink-zir01ui6s-001.html
# https://www.zalando.nl/desigual-overhemd-brown-zir01u6np-001.html
# https://www.zalando.nl/marks-and-spencer-london-zakelijk-overhemd-red-zir012g3w-001.html
# https://www.zalando.nl/soliver-overhemd-blue-zir00q5iu-001.html
# https://www.zalando.nl/hilfiger-denim-overhemd-blue-zir00ptz4-001.html
# https://www.zalando.nl/signum-overhemd-orange-zir00q58q-001.html
# https://www.zalando.nl/asos-overhemd-blue-zir00q0g2-001.html
# https://www.zalando.nl/marks-and-spencer-london-overhemd-multi-colored-zir00q5su-001.html
# https://www.zalando.nl/superdry-overhemd-blue-zir00q5md-001.html
# https://www.zalando.nl/boss-overhemd-blue-zir01uiyh-001.html
# https://www.zalando.nl/jean-paul-berlin-overhemd-blue-zir00q5am-001.html
# https://www.zalando.nl/barbour-overhemd-green-zir01ub8h-001.html
# https://www.zalando.nl/next-overhemd-grey-zir00q5b1-001.html
# https://www.zalando.nl/calvin-klein-overhemd-blue-zir00ucwa-001.html
# https://www.zalando.nl/marks-and-spencer-london-zakelijk-overhemd-red-zir012eeu-001.html
# https://www.zalando.nl/next-overhemd-blue-zir00q500-001.html
# https://www.zalando.nl/pepe-jeans-overhemd-blue-zir00q5oe-001.html
# https://www.zalando.nl/jack-and-jones-overhemd-black-zir01u9x3-001.html
# https://www.zalando.nl/marks-and-spencer-london-overhemd-blue-zir00ucug-001.html
# https://www.zalando.nl/garcia-overhemd-blue-zir01u5df-001.html
# https://www.zalando.nl/diesel-overhemd-grey-zir01u2rz-001.html
# https://www.zalando.nl/jack-and-jones-overhemd-blue-zir00q0ba-001.html
# https://www.zalando.nl/scotch-and-soda-overhemd-blue-zir00q50x-001.html
# https://www.zalando.nl/tommy-hilfiger-overhemd-blue-zir00ptzt-001.html
# https://www.zalando.nl/next-overhemd-brown-zir00q0fp-001.html
# https://www.zalando.nl/seidensticker-zakelijk-overhemd-pink-zir00q0fz-001.html
# https://www.zalando.nl/next-overhemd-black-zir01u57z-001.html
# https://www.zalando.nl/burton-overhemd-grey-zir00ucu2-001.html
# https://www.zalando.nl/lerros-overhemd-blue-zir01ujxe-001.html
# https://www.zalando.nl/marks-and-spencer-london-overhemd-blue-zir00q511-001.html
# https://www.zalando.nl/next-zakelijk-overhemd-beige-zir00tvm5-001.html
# https://www.zalando.nl/pierre-cardin-overhemd-pink-zir012ko0-001.html
# https://www.zalando.nl/marks-and-spencer-zakelijk-overhemd-white-zir01u9u6-001.html
# https://www.zalando.nl/marc-opolo-overhemd-grey-zir01u54k-001.html
# https://www.zalando.nl/gant-overhemd-multi-colored-zir01uacd-001.html
# https://www.zalando.nl/christian-berg-overhemd-blue-zir00q5lq-001.html
# https://www.zalando.nl/gant-zakelijk-overhemd-blue-zir012eee-001.html
# https://www.zalando.nl/eterna-zakelijk-overhemd-pink-zir00q0ql-001.html
# https://www.zalando.nl/seidensticker-overhemd-orange-zir00q5gd-001.html
# https://www.zalando.nl/next-overhemd-blue-zir01uk62-001.html
# https://www.zalando.nl/selected-homme-overhemd-blue-zir01u7ue-001.html
# https://www.zalando.nl/eterna-overhemd-grey-zir00q50m-001.html
# https://www.zalando.nl/gant-overhemd-green-zir00q5vv-001.html
# https://www.zalando.nl/burton-overhemd-white-zir012hgn-001.html
# https://www.zalando.nl/joop-zakelijk-overhemd-white-zir00q0gy-001.html
# https://www.zalando.nl/camel-active-overhemd-grey-zir01u6g6-001.html
# https://www.zalando.nl/next-overhemd-multi-colored-zir00q0qv-001.html
# https://www.zalando.nl/tom-tailor-denim-overhemd-purple-zir00q0hy-001.html
# https://www.zalando.nl/filippa-k-zakelijk-overhemd-blue-zir01u4fk-001.html
# https://www.zalando.nl/scotch-and-soda-overhemd-blue-zir012mki-001.html
# https://www.zalando.nl/next-overhemd-white-zir00q5t9-001.html
# https://www.zalando.nl/next-overhemd-blue-zir00tvcx-001.html
# https://www.zalando.nl/tommy-hilfiger-overhemd-red-zir00ptow-001.html
# https://www.zalando.nl/next-zakelijk-overhemd-grey-zir00q0q5-001.html
# https://www.zalando.nl/ted-baker-overhemd-blue-zir01u7ev-001.html
# https://www.zalando.nl/seidensticker-zakelijk-overhemd-beige-zir01u6v5-001.html
# https://www.zalando.nl/the-kooples-overhemd-blue-zir01u6qo-001.html
# https://www.zalando.nl/hollister-co-overhemd-blue-zir01u70a-001.html
# https://www.zalando.nl/gap-overhemd-grey-zir01u37c-001.html
# https://www.zalando.nl/next-overhemd-blue-zir01ui51-001.html
# https://www.zalando.nl/soliver-overhemd-red-zir00q5bw-001.html
# https://www.zalando.nl/next-zakelijk-overhemd-grey-zir00tv8q-001.html

# %%
len(product_urls_po)
# Out:
# 84

# %% [markdown]
# ### 1.5 Collect information from products
# The information gathered per product for the Zalando's Pre-owned men's clothing section includes product url, brand name, category type, color, size, delivery time in working days and price in euros.

# %%
def get_product_pages_po(products_po):
    product_pages_po = []
    
    for url_po in product_urls_po: 
        res_po = requests.get(url_po, headers = user_agent)
        soup_po = BeautifulSoup(res_po.text, "html.parser")
        attributes_po = soup_po.find_all(class_="DT5BTM VHXqc_ rceRmQ _4NtqZU mIlIve")
        delivery_po = soup_po.find(class_="PBR5VH _0xLoFW EJ4MLB")
        prices_po = soup_po.find("div", class_="_0xLoFW vSgP6A _7ckuOK")
        
        for attribute_po in attributes_po:    
            product_po = attribute_po.find("h3", class_="SZKKsK mt1kvu ka2E9k uMhVZi FxZV-M pVrzNP _5Yd-hZ").text
            category_po = attribute_po.find("span", class_="EKabf7 R_QwOV").text
            color_po = attribute_po.find("span", class_="RYghuO u-6V88 ka2E9k uMhVZi dgII7d pVrzNP").text
            size_po = attribute_po.find("span", class_="RYghuO _7Cm1F9 ka2E9k uMhVZi dgII7d pVrzNP").text
            
            try:
                delivery_time_po = delivery_po.find("span", class_="u-6V88 ka2E9k uMhVZi dgII7d RYghuO pVrzNP").text
                delivery_time_po = delivery_time_po.replace("werkdagen", "")
                delivery_time_po = delivery_time_po.replace(" ", "")
                delivery_time_po = delivery_time_po.replace("-", "--")
            except:
                delivery_time_po = "no delivery time"

            try:
                price_po = prices_po.find("span", class_="pVrzNP").text
                price_po = price_po.replace(u'€\xa0', u' ')
                price_po = price_po.replace(" ", "")
                price_po = price_po.replace(",", ".")
            except:
                price_po = prices_po.find("span", class_="uqkIZw").text
                price_po = price_po.replace(u'€\xa0', u' ')
                price_po = price_po.replace(" ", "")
                price_po = price_po.replace(",", ".")

            product_pages_po.append({"url": url_po,
                                 "brand": product_po,
                                 "category": category_po,
                                 "price": price_po,
                                 "size": size_po,
                                 "delivery_time": delivery_time_po,
                                 "color": color_po})
   
    return product_pages_po

# %%
product_attributes_po = get_product_pages_po(product_urls_po)

time.sleep(5)

product_attributes_po
# Out:
# [{'url': 'https://www.zalando.nl/oakley-overhemd-blue-zir01u72p-001.html',
#   'brand': 'Oakley',
#   'category': 'Overhemd',
#   'price': '49.50',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/tom-tailor-overhemd-grey-zir00q0hu-001.html',
#   'brand': 'TOM TAILOR',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-overhemd-blue-zir00nb0p-001.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'Overhemd',
#   'price': '38.60',
#   'size': 'XXL',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/lauren-ralph-lauren-overhemd-blue-zir00q54e-001.html',
#   'brand': 'Lauren Ralph Lauren',
#   'category': 'Overhemd',
#   'price': '35.90',
#   'size': '42',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-overhemd-blue-zir00n9x9-001.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': 'Overhemd',
#   'price': '36.30',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/ted-baker-overhemd-blue-zir00q544-001.html',
#   'brand': 'Ted Baker',
#   'category': 'Overhemd',
#   'price': '32.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/levis-overhemd-blue-zir00ptv5-001.html',
#   'brand': "Levi's®",
#   'category': 'Overhemd',
#   'price': '22.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/levis-overhemd-blue-zir00ptpx-001.html',
#   'brand': "Levi's®",
#   'category': 'Overhemd',
#   'price': '22.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/paul-smith-overhemd-taupe-zir01ub9d-001.html',
#   'brand': 'Paul Smith',
#   'category': 'Overhemd',
#   'price': '43.80',
#   'size': '39',
#   'delivery_time': 'no delivery time',
#   'color': 'taupe'},
#  {'url': 'https://www.zalando.nl/eterna-overhemd-green-zir01u48a-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '23.90',
#   'size': '42',
#   'delivery_time': 'no delivery time',
#   'color': 'green'},
#  {'url': 'https://www.zalando.nl/qs-by-soliver-t-shirt-print-grey-zir016qsk-001.html',
#   'brand': 'QS by s.Oliver',
#   'category': 'T-shirt print',
#   'price': '10.00',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/daniel-hechter-zakelijk-overhemd-brown-zir00ue0x-001.html',
#   'brand': 'Daniel Hechter',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': '42',
#   'delivery_time': 'no delivery time',
#   'color': 'brown'},
#  {'url': 'https://www.zalando.nl/eterna-zakelijk-overhemd-white-zir01uj8d-001.html',
#   'brand': 'Eterna',
#   'category': 'Zakelijk overhemd',
#   'price': '24.90',
#   'size': '44',
#   'delivery_time': 'no delivery time',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/scotch-and-soda-overhemd-green-zir01ujr1-001.html',
#   'brand': 'Scotch & Soda',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'green'},
#  {'url': 'https://www.zalando.nl/soliver-selection-overhemd-blue-zir00q0bb-001.html',
#   'brand': 's.Oliver Selection',
#   'category': 'Overhemd',
#   'price': '17.90',
#   'size': '37',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/hollister-co-overhemd-blue-zir01u9y4-001.html',
#   'brand': 'Hollister Co.',
#   'category': 'Overhemd',
#   'price': '16.50',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/samsoee-samsoee-overhemd-blue-zir01u4xy-001.html',
#   'brand': 'Samsøe Samsøe',
#   'category': 'Overhemd',
#   'price': '25.40',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-london-overhemd-blue-zir00q51c-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '18.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/burton-overhemd-black-zir00q5j3-001.html',
#   'brand': 'Burton',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-overhemd-white-zir00q9tk-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Overhemd',
#   'price': '23.90',
#   'size': 'S',
#   'delivery_time': 'no delivery time',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/next-overhemd-beige-zir00q63e-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': '39',
#   'delivery_time': 'no delivery time',
#   'color': 'beige'},
#  {'url': 'https://www.zalando.nl/gap-overhemd-green-zir00q5gg-001.html',
#   'brand': 'GAP',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': 'XXL',
#   'delivery_time': 'no delivery time',
#   'color': 'green'},
#  {'url': 'https://www.zalando.nl/van-laack-overhemd-pink-zir01ui6s-001.html',
#   'brand': 'van Laack',
#   'category': 'Overhemd',
#   'price': '43.20',
#   'size': '40',
#   'delivery_time': 'no delivery time',
#   'color': 'pink'},
#  {'url': 'https://www.zalando.nl/desigual-overhemd-brown-zir01u6np-001.html',
#   'brand': 'Desigual',
#   'category': 'Overhemd',
#   'price': '16.40',
#   'size': 'S',
#   'delivery_time': 'no delivery time',
#   'color': 'brown'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-london-zakelijk-overhemd-red-zir012g3w-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Zakelijk overhemd',
#   'price': '17.90',
#   'size': '39',
#   'delivery_time': 'no delivery time',
#   'color': 'red'},
#  {'url': 'https://www.zalando.nl/soliver-overhemd-blue-zir00q5iu-001.html',
#   'brand': 's.Oliver',
#   'category': 'Overhemd',
#   'price': '18.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/hilfiger-denim-overhemd-blue-zir00ptz4-001.html',
#   'brand': 'Hilfiger Denim',
#   'category': 'Overhemd',
#   'price': '21.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/signum-overhemd-orange-zir00q58q-001.html',
#   'brand': 'Signum',
#   'category': 'Overhemd',
#   'price': '51.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'orange'},
#  {'url': 'https://www.zalando.nl/asos-overhemd-blue-zir00q0g2-001.html',
#   'brand': 'ASOS',
#   'category': 'Overhemd',
#   'price': '17.90',
#   'size': 'XS',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-london-overhemd-multi-colored-zir00q5su-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'multi-colored'},
#  {'url': 'https://www.zalando.nl/superdry-overhemd-blue-zir00q5md-001.html',
#   'brand': 'Superdry',
#   'category': 'Overhemd',
#   'price': '25.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/boss-overhemd-blue-zir01uiyh-001.html',
#   'brand': 'BOSS',
#   'category': 'Overhemd',
#   'price': '27.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/jean-paul-berlin-overhemd-blue-zir00q5am-001.html',
#   'brand': 'Jean Paul Berlin',
#   'category': 'Overhemd',
#   'price': '21.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/barbour-overhemd-green-zir01ub8h-001.html',
#   'brand': 'Barbour',
#   'category': 'Overhemd',
#   'price': '24.70',
#   'size': 'S',
#   'delivery_time': 'no delivery time',
#   'color': 'green'},
#  {'url': 'https://www.zalando.nl/next-overhemd-grey-zir00q5b1-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': '43',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/calvin-klein-overhemd-blue-zir00ucwa-001.html',
#   'brand': 'Calvin Klein',
#   'category': 'Overhemd',
#   'price': '25.90',
#   'size': '38',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-london-zakelijk-overhemd-red-zir012eeu-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Zakelijk overhemd',
#   'price': '18.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'red'},
#  {'url': 'https://www.zalando.nl/next-overhemd-blue-zir00q500-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '18.90',
#   'size': '40',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/pepe-jeans-overhemd-blue-zir00q5oe-001.html',
#   'brand': 'Pepe Jeans',
#   'category': 'Overhemd',
#   'price': '17.90',
#   'size': 'S',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-overhemd-black-zir01u9x3-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Overhemd',
#   'price': '19.40',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-london-overhemd-blue-zir00ucug-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '15.90',
#   'size': '39',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/garcia-overhemd-blue-zir01u5df-001.html',
#   'brand': 'Garcia',
#   'category': 'Overhemd',
#   'price': '19.40',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/diesel-overhemd-grey-zir01u2rz-001.html',
#   'brand': 'Diesel',
#   'category': 'Overhemd',
#   'price': '16.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-overhemd-blue-zir00q0ba-001.html',
#   'brand': 'Jack & Jones',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/scotch-and-soda-overhemd-blue-zir00q50x-001.html',
#   'brand': 'Scotch & Soda',
#   'category': 'Overhemd',
#   'price': '22.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-overhemd-blue-zir00ptzt-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Overhemd',
#   'price': '27.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/next-overhemd-brown-zir00q0fp-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'brown'},
#  {'url': 'https://www.zalando.nl/seidensticker-zakelijk-overhemd-pink-zir00q0fz-001.html',
#   'brand': 'Seidensticker',
#   'category': 'Zakelijk overhemd',
#   'price': '18.90',
#   'size': '41',
#   'delivery_time': 'no delivery time',
#   'color': 'pink'},
#  {'url': 'https://www.zalando.nl/next-overhemd-black-zir01u57z-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '16.40',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/burton-overhemd-grey-zir00ucu2-001.html',
#   'brand': 'Burton',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': '39',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/lerros-overhemd-blue-zir01ujxe-001.html',
#   'brand': 'LERROS',
#   'category': 'Overhemd',
#   'price': '19.10',
#   'size': 'XXL',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-london-overhemd-blue-zir00q511-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Overhemd',
#   'price': '17.90',
#   'size': '41',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/next-zakelijk-overhemd-beige-zir00tvm5-001.html',
#   'brand': 'Next',
#   'category': 'Zakelijk overhemd',
#   'price': '17.90',
#   'size': '41',
#   'delivery_time': 'no delivery time',
#   'color': 'beige'},
#  {'url': 'https://www.zalando.nl/pierre-cardin-overhemd-pink-zir012ko0-001.html',
#   'brand': 'Pierre Cardin',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': '39',
#   'delivery_time': 'no delivery time',
#   'color': 'pink'},
#  {'url': 'https://www.zalando.nl/marks-and-spencer-zakelijk-overhemd-white-zir01u9u6-001.html',
#   'brand': 'Marks & Spencer',
#   'category': 'Zakelijk overhemd',
#   'price': '16.10',
#   'size': '43',
#   'delivery_time': 'no delivery time',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/marc-opolo-overhemd-grey-zir01u54k-001.html',
#   'brand': "Marc O'Polo",
#   'category': 'Overhemd',
#   'price': '18.10',
#   'size': 'S',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/gant-overhemd-multi-colored-zir01uacd-001.html',
#   'brand': 'GANT',
#   'category': 'Overhemd',
#   'price': '27.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'multi colored'},
#  {'url': 'https://www.zalando.nl/christian-berg-overhemd-blue-zir00q5lq-001.html',
#   'brand': 'Christian Berg',
#   'category': 'Overhemd',
#   'price': '23.90',
#   'size': '45',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/gant-zakelijk-overhemd-blue-zir012eee-001.html',
#   'brand': 'GANT',
#   'category': 'Zakelijk overhemd',
#   'price': '26.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/eterna-zakelijk-overhemd-pink-zir00q0ql-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '17.90',
#   'size': '44',
#   'delivery_time': 'no delivery time',
#   'color': 'pink'},
#  {'url': 'https://www.zalando.nl/seidensticker-overhemd-orange-zir00q5gd-001.html',
#   'brand': 'Seidensticker',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': 'XXL',
#   'delivery_time': 'no delivery time',
#   'color': 'orange'},
#  {'url': 'https://www.zalando.nl/next-overhemd-blue-zir01uk62-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '17.20',
#   'size': '36',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/selected-homme-overhemd-blue-zir01u7ue-001.html',
#   'brand': 'Selected Homme',
#   'category': 'Overhemd',
#   'price': '20.50',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/eterna-overhemd-grey-zir00q50m-001.html',
#   'brand': 'Eterna',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': '41',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/gant-overhemd-green-zir00q5vv-001.html',
#   'brand': 'GANT',
#   'category': 'Overhemd',
#   'price': '29.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'green'},
#  {'url': 'https://www.zalando.nl/burton-overhemd-white-zir012hgn-001.html',
#   'brand': 'Burton',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/joop-zakelijk-overhemd-white-zir00q0gy-001.html',
#   'brand': 'JOOP!',
#   'category': 'Overhemd',
#   'price': '25.90',
#   'size': '42',
#   'delivery_time': 'no delivery time',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/camel-active-overhemd-grey-zir01u6g6-001.html',
#   'brand': 'camel active',
#   'category': 'Overhemd',
#   'price': '18.40',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/next-overhemd-multi-colored-zir00q0qv-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '15.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'multicolored'},
#  {'url': 'https://www.zalando.nl/tom-tailor-denim-overhemd-purple-zir00q0hy-001.html',
#   'brand': 'TOM TAILOR DENIM',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': 'S',
#   'delivery_time': 'no delivery time',
#   'color': 'purple'},
#  {'url': 'https://www.zalando.nl/filippa-k-zakelijk-overhemd-blue-zir01u4fk-001.html',
#   'brand': 'Filippa K',
#   'category': 'Zakelijk overhemd',
#   'price': '31.40',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/scotch-and-soda-overhemd-blue-zir012mki-001.html',
#   'brand': 'Scotch & Soda',
#   'category': 'Overhemd',
#   'price': '24.90',
#   'size': 'L',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/next-overhemd-white-zir00q5t9-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '19.90',
#   'size': '38',
#   'delivery_time': 'no delivery time',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/next-overhemd-blue-zir00tvcx-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '20.90',
#   'size': '41',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-overhemd-red-zir00ptow-001.html',
#   'brand': 'Tommy Hilfiger',
#   'category': 'Overhemd',
#   'price': '23.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'red'},
#  {'url': 'https://www.zalando.nl/next-zakelijk-overhemd-grey-zir00q0q5-001.html',
#   'brand': 'Next',
#   'category': 'Zakelijk overhemd',
#   'price': '17.90',
#   'size': '40',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/ted-baker-overhemd-blue-zir01u7ev-001.html',
#   'brand': 'Ted Baker',
#   'category': 'Overhemd',
#   'price': '35.70',
#   'size': 'XS',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/seidensticker-zakelijk-overhemd-beige-zir01u6v5-001.html',
#   'brand': 'Seidensticker',
#   'category': 'Zakelijk overhemd',
#   'price': '20.90',
#   'size': '45',
#   'delivery_time': 'no delivery time',
#   'color': 'beige'},
#  {'url': 'https://www.zalando.nl/the-kooples-overhemd-blue-zir01u6qo-001.html',
#   'brand': 'The Kooples',
#   'category': 'Overhemd',
#   'price': '41.40',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/hollister-co-overhemd-blue-zir01u70a-001.html',
#   'brand': 'Hollister Co.',
#   'category': 'Overhemd',
#   'price': '15.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/gap-overhemd-grey-zir01u37c-001.html',
#   'brand': 'GAP',
#   'category': 'Overhemd',
#   'price': '18.90',
#   'size': 'M',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'},
#  {'url': 'https://www.zalando.nl/next-overhemd-blue-zir01ui51-001.html',
#   'brand': 'Next',
#   'category': 'Overhemd',
#   'price': '17.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'blue'},
#  {'url': 'https://www.zalando.nl/soliver-overhemd-red-zir00q5bw-001.html',
#   'brand': 's.Oliver',
#   'category': 'Overhemd',
#   'price': '17.90',
#   'size': 'XL',
#   'delivery_time': 'no delivery time',
#   'color': 'red'},
#  {'url': 'https://www.zalando.nl/next-zakelijk-overhemd-grey-zir00tv8q-001.html',
#   'brand': 'Next',
#   'category': 'Zakelijk overhemd',
#   'price': '19.90',
#   'size': '39',
#   'delivery_time': 'no delivery time',
#   'color': 'grey'}]

# %% [markdown]
# ### 1.6 Write collected information to a CSV file

# %%
with open("product_description_pre_owned.csv", "w", encoding = 'utf-8', newline='') as csv_file: 
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(["url", "brand", "category", "price", "size", "delivery_time", "color", "date"])
    now_po = datetime.now()
    for product_po in product_attributes_po: 
        writer.writerow([product_po['url'], product_po['brand'], product_po['category'], product_po['price'], product_po['size'], product_po['delivery_time'], product_po["color"], now_po])
print('done!')
# Out:
# done!

# %% [markdown]
# ##  Chapter 2: Zalando scraper | Regular Heren
# The second part of the web scraper contains code to scrape the Zalando web page(s) of the Zalando Regular Men's clothing section (https://www.zalando.nl/herenkleding/). The variables used as an outcome of this part of the scraper do not have a particular denote as indication.

# %% [markdown]
# ### 2.1 Run Chromedriver

# %%
# use webdriver.Chrome()
driver = webdriver.Chrome(ChromeDriverManager().install())

# run Zalando Herenkleding
driver.get("https://www.zalando.nl/herenkleding/")
time.sleep(10)
print("done")
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Systeembeheer\.wdm\drivers\chromedriver\win32\99.0.4844.51]
# done

# %% [markdown]
# ### 2.2 Automatic acceptation of cookies
# The cookies are automatically accepted to close pop-ups before proceeding with web scraping.

# %%
driver.find_element_by_id("uc-btn-accept-banner").click()

# %% [markdown]
# ### 2.3 Collect page urls

# %%
base_url = "https://www.zalando.nl/herenkleding/?p="
counter = 1

def generate_page_urls(base_url, num_pages):
    page_urls = []
    
    for counter in range (1, num_pages + 1):
        full_url = base_url + str(counter) + "&order=activation_date"
        page_urls.append(full_url)
    
    return page_urls

# %%
page_urls = generate_page_urls(base_url, 1) 

generate_page_urls("https://www.zalando.nl/herenkleding/?p=", 20)
# Out:
# ['https://www.zalando.nl/herenkleding/?p=1&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=2&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=3&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=4&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=5&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=6&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=7&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=8&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=9&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=10&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=11&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=12&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=13&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=14&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=15&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=16&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=17&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=18&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=19&order=activation_date',
#  'https://www.zalando.nl/herenkleding/?p=20&order=activation_date']

# %% [markdown]
# ### 2.4 Collect product urls

# %%
def create_product_urls(page_urls):
    product_urls = []
    cnt=1
    for page_url in page_urls:
        cnt+=1
        driver.get(page_url)
        time.sleep(5)
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        products = soup.find_all("div", class_= "DT5BTM w8MdNG cYylcv QylWsg _75qWlu iOzucJ JT3_zV DvypSJ")
        substring_outfit = "/outfits/"
        print(len(products))
        sleep(1)

        for product in products:
            try:
                product_url = product.find("a").attrs["href"]
                
                if search(substring_outfit, product_url):
                    product_url = product_url.rsplit('/outfits', 1)
                    product_url = product_url.pop(0)
                else:
                    print(product_url)
                    product_urls.append(product_url)

            except:
                print("dit is geen product")
                
    return product_urls

# %%
product_urls = create_product_urls(page_urls)
# Out:
# 85
# https://www.zalando.nl/only-and-sons-onstroy-tee-unisex-t-shirt-print-grey-pinstripe-os3210002-c11.html
# https://www.zalando.nl/jack-and-jones-top-black-ja222o4bt-q11.html
# https://www.zalando.nl/jack-and-jones-top-nirvana-ja222o4bt-i11.html
# https://www.zalando.nl/tommy-jeans-longsleeve-black-tob22o0gn-q11.html
# https://www.zalando.nl/tommy-hilfiger-camo-logo-tee-t-shirt-basic-navy-to122o0iz-k11.html
# https://www.zalando.nl/tommy-jeans-overhemd-sky-blue-tob22d08a-k11.html
# https://www.zalando.nl/clockhouse-t-shirt-basic-black-cfi22o00k-q11.html
# https://www.zalando.nl/canda-poloshirt-black-c6f22p029-q11.html
# https://www.zalando.nl/state-of-art-press-buttons-overhemd-navy-plain-oa422d0nv-k11.html
# https://www.zalando.nl/cadeaubonnen
# https://www.zalando.nl/state-of-art-overhemd-cobalt-beige-oa422d0of-k11.html
# https://www.zalando.nl/the-kooples-poloshirt-black-tha22p01g-q11.html
# https://www.zalando.nl/jack-and-jones-t-shirt-print-sand-ja222o4gc-b11.html
# https://www.zalando.nl/state-of-art-colour-blocks-t-shirt-print-light-greynavy-oa422o00r-c12.html
# https://www.zalando.nl/henry-tiger-disney-classics-unisex-platypus-love-t-shirt-print-melange-black-h3a21026c-q11.html
# https://www.zalando.nl/clockhouse-overhemd-white-cfi22d004-a11.html
# https://www.zalando.nl/henry-tiger-disney-unisex-aurora-comic-t-shirt-print-melange-grey-h3a21026i-c11.html
# https://www.zalando.nl/jack-and-jones-jjirick-jjioriginal-jeansshort-black-denim-ja222f0te-q11.html
# https://www.zalando.nl/gant-archive-shield-t-shirt-print-pistazie-ga322o02w-m13.html
# https://www.zalando.nl/origin-of-hearts-mori-kimono-shirt-overhemd-black-ors22d005-q11.html
# https://www.zalando.nl/tommy-hilfiger-medium-drawstring-print-zwemshorts-multi-coloured-to182h05h-t11.html
# https://www.zalando.nl/state-of-art-supima-poloshirt-leafgreen-plain-oa422p04f-m11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a21024a-c11.html
# https://www.zalando.nl/henry-tiger-disney-aladdin-t-shirt-print-melange-grey-h3a21022y-c11.html
# https://www.zalando.nl/origin-of-hearts-jima-kimono-shirt-overhemd-black-ors22d006-q11.html
# https://www.zalando.nl/lyle-and-scott-tipped-poloshirt-electric-cobaltdark-navy-ly222p039-k13.html
# https://www.zalando.nl/buratti-t-shirt-print-black-bus22o01t-q11.html
# https://www.zalando.nl/revolution-terry-cuban-overhemd-offwhite-re622d047-a11.html
# https://www.zalando.nl/national-geographic-t-shirt-basic-black-nam210002-q11.html
# https://www.zalando.nl/eterna-comfort-fit-overhemd-hellblau-weiss-2et22d3w2-k11.html
# https://www.zalando.nl/origin-of-hearts-flores-kimono-overhemd-royal-blue-ors22d007-k11.html
# https://www.zalando.nl/massimo-dutti-short-sleeve-poloshirt-beige-m3i22p082-b11.html
# https://www.zalando.nl/endless-nights-flame-unisex-overhemd-khaki-eno21002l-n11.html
# https://www.zalando.nl/esprit-t-shirt-print-navy-es122o0ye-k11.html
# https://www.zalando.nl/boss-paul-poloshirt-light-grey-bb122p0i9-c11.html
# https://www.zalando.nl/harmont-and-blaine-t-shirt-print-grigio-chiaro-hr422o01h-c11.html
# https://www.zalando.nl/esprit-t-shirt-print-sand-es122o0ye-b11.html
# https://www.zalando.nl/henry-tiger-disney-shamrock-t-shirt-print-melange-grey-h3a210230-c11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a21025u-c11.html
# https://www.zalando.nl/neil-barrett-fair-isle-thunderbolt-sweater-met-rits-cobaltsage-4ne21000h-k11.html
# https://www.zalando.nl/endless-nights-space-unisex-longsleeve-pistachio-eno21001j-m11.html
# https://www.zalando.nl/jack-and-jones-jjibowie-jjshorts-solid-shorts-oxford-tan-ja222f0px-b11.html
# https://www.zalando.nl/polo-ralph-lauren-long-sleeve-sport-shirt-overhemd-bluewhite-po222d0u5-a11.html
# https://www.zalando.nl/hugo-elisha-zakelijk-overhemd-navy-hu722d0lp-k12.html
# https://www.zalando.nl/eterna-comfort-fit-overhemd-azurblau-2et22d3vv-k11.html
# https://www.zalando.nl/harmont-and-blaine-overhemd-blu-screziato-hr422d06t-k12.html
# https://www.zalando.nl/harmont-and-blaine-overhemd-dark-blue-hr422d06y-k11.html
# https://www.zalando.nl/harmont-and-blaine-overhemd-blu-scuro-hr422d06t-k11.html
# https://www.zalando.nl/harmont-and-blaine-overhemd-light-red-hr422d06y-g11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-black-h3a22o0di-q11.html
# https://www.zalando.nl/harmont-and-blaine-overhemd-cognac-hr422d06t-o11.html
# https://www.zalando.nl/tommy-hilfiger-poloshirt-breezy-blue-to122p0a1-k19.html
# https://www.zalando.nl/harmont-and-blaine-t-shirt-print-grigio-chiaro-hr422o01n-c11.html
# https://www.zalando.nl/harmont-and-blaine-t-shirt-print-oliva-hr422o01n-n11.html
# https://www.zalando.nl/jordan-brand-crew-t-shirt-print-plum-fog-joc22o065-i11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-black-h3a21026s-q11.html
# https://www.zalando.nl/eterna-langarm-slim-fit-stretch-zakelijk-overhemd-weiss-2et22d3un-a11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-black-h3a21025t-q11.html
# https://www.zalando.nl/vivienne-westwood-drunken-bomber-unisex-bomberjacks-tartan-vw921000i-c11.html
# https://www.zalando.nl/jack-and-jones-glenn-original-na-013-jeans-skinny-fit-blue-denim-ja222g1qs-k11.html
# https://www.zalando.nl/tom-tailor-poloshirt-sky-captain-blue-white-melange-to222o14r-k12.html
# https://www.zalando.nl/neil-barrett-fair-isle-thunderbolt-sweater-met-rits-naturaldark-beige-4ne21000h-a11.html
# https://www.zalando.nl/massimo-dutti-overhemd-dark-blue-m3i22d0q3-k11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a21025n-c11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a210246-c11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-white-h3a21025m-a11.html
# https://www.zalando.nl/pullandbear-oversized-sweater-beige-puc21j0tn-b11.html
# https://www.zalando.nl/jack-and-jones-jprblacardiff-shirt-zakelijk-overhemd-black-ja222d253-q11.html
# https://www.zalando.nl/young-poets-society-aris-broek-vintage-black-yoj22e00f-q11.html
# https://www.zalando.nl/boggi-milano-overhemd-green-bq122d020-m11.html
# https://www.zalando.nl/camel-active-kurzarm-aus-t-shirt-basic-green-ca522o04e-m11.html
# https://www.zalando.nl/state-of-art-overhemd-cobalt-white-oa422d0og-k11.html
# https://www.zalando.nl/brave-soul-t-shirt-print-optic-whitejet-black-brh22o0bw-a11.html
# https://www.zalando.nl/ellesse-t-shirt-print-gruen-el922o0df-m11.html
# https://www.zalando.nl/boggi-milano-overhemd-light-blu-bq122d01y-k11.html
# https://www.zalando.nl/henry-tiger-disney-classics-unisex-no-rules-t-shirt-print-melange-grey-h3a21026j-c11.html
# https://www.zalando.nl/henry-tiger-marvel-unisex-home-couple-t-shirt-print-black-h3a22o0d0-q11.html
# https://www.zalando.nl/henry-tiger-disney-classics-rebel-heart-t-shirt-print-melange-grey-h3a210229-c11.html
# https://www.zalando.nl/kinetix-basic-c-neck-t-shirt-basic-grey-mel-kiw22o002-c11.html
# https://www.zalando.nl/anerkjendt-akkian-block-overhemd-tofu-a2322d05y-a11.html
# https://www.zalando.nl/pier-one-overhemd-black-pi922d0co-q11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-melange-black-h3a21025z-q11.html
# https://www.zalando.nl/jack-and-jones-jorollie-solid-overhemd-black-ja222d211-q11.html
# https://www.zalando.nl/michael-kors-overhemd-chambray-1mi22d06y-k11.html
# https://www.zalando.nl/henry-tiger-t-shirt-print-melange-black-h3a21025y-q11.html

# %% [markdown]
# ### 2.5 Collect information from products
# The information gathered per product for the Zalando's Regular men's clothing section includes product url, brand name, category type, color, delivery time in working days and price in euros.
# *NOTE: Since collecting the sizes was made complicated by a dropdown menu, it was not possible to scrape this information. The assumptions was made that for the regular offering of men's clothing all sizes are available.*

# %%
print(len(product_urls))
# Out:
# 85

# %%
def get_product_pages(products):
    product_pages = []
    
    for url in product_urls: 
        res = requests.get(url, headers = user_agent)
        soup = BeautifulSoup(res.text, "html.parser")
        attributes = soup.find_all(class_="DT5BTM VHXqc_ rceRmQ _4NtqZU mIlIve")
        delivery = soup.find(class_="PBR5VH _0xLoFW EJ4MLB")
        prices = soup.find("div", class_="_0xLoFW vSgP6A _7ckuOK")
        
        for attribute in attributes:    
            product = attribute.find("h3", class_="SZKKsK mt1kvu ka2E9k uMhVZi FxZV-M pVrzNP _5Yd-hZ").text
            category = attribute.find("span", class_="EKabf7 R_QwOV").text
            color = attribute.find("span", class_="RYghuO u-6V88 ka2E9k uMhVZi dgII7d pVrzNP").text
            
            try:
                delivery_time = delivery.find("span", class_="RYghuO u-6V88 ka2E9k uMhVZi dgII7d pVrzNP").text
                delivery_time = delivery_time.replace("werkdagen", "")
                delivery_time = delivery_time.replace(" ", "")
                delivery_time = delivery_time.replace("-", "--")
            except:
                delivery_time = "no delivery time"
            
            substring = " - "            
            if search(substring, category):
                category = category.rsplit(' -', 1)
                category = category.pop(1)
                
            else:
                category
                
            try:
                price = prices.find("span", class_="pVrzNP").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")
            except:
                price = prices.find("span", class_="uqkIZw").text
                price = price.replace(u'€\xa0', u' ')
                price = price.replace(" ", "")
            
            product_pages.append({"url": url,
                                 "brand": product,
                                 "category": category,
                                 "price": price,
                                 "delivery_time": delivery_time,
                                 "color": color})
   
    return product_pages
print("done")
# Out:
# done

# %%
product_attributes = get_product_pages(product_urls)

time.sleep(5)

product_attributes
# Out:
# [{'url': 'https://www.zalando.nl/only-and-sons-onstroy-tee-unisex-t-shirt-print-grey-pinstripe-os3210002-c11.html',
#   'brand': 'Only & Sons',
#   'category': ' T-shirt print',
#   'price': '16,99',
#   'delivery_time': '1--2',
#   'color': 'grey pinstripe'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-top-black-ja222o4bt-q11.html',
#   'brand': 'Jack & Jones',
#   'category': 'Top',
#   'price': '12,99',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-top-nirvana-ja222o4bt-i11.html',
#   'brand': 'Jack & Jones',
#   'category': 'Top',
#   'price': '12,99',
#   'delivery_time': '3--6',
#   'color': 'nirvana'},
#  {'url': 'https://www.zalando.nl/tommy-jeans-longsleeve-black-tob22o0gn-q11.html',
#   'brand': 'Tommy Jeans',
#   'category': 'Longsleeve',
#   'price': '49,90',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-camo-logo-tee-t-shirt-basic-navy-to122o0iz-k11.html',
#   'brand': 'Tommy Hilfiger',
#   'category': ' T-shirt basic',
#   'price': '59,90',
#   'delivery_time': '3--6',
#   'color': 'navy'},
#  {'url': 'https://www.zalando.nl/tommy-jeans-overhemd-sky-blue-tob22d08a-k11.html',
#   'brand': 'Tommy Jeans',
#   'category': ' Overhemd',
#   'price': '98,89',
#   'delivery_time': '3--6',
#   'color': 'sky blue'},
#  {'url': 'https://www.zalando.nl/clockhouse-t-shirt-basic-black-cfi22o00k-q11.html',
#   'brand': 'CLOCKHOUSE',
#   'category': 'T-shirt basic',
#   'price': '6,99',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/canda-poloshirt-black-c6f22p029-q11.html',
#   'brand': 'C&A',
#   'category': 'Poloshirt',
#   'price': '9,99',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/state-of-art-press-buttons-overhemd-navy-plain-oa422d0nv-k11.html',
#   'brand': 'State of Art',
#   'category': ' Overhemd',
#   'price': '99,95',
#   'delivery_time': '3--6',
#   'color': 'navy plain'},
#  {'url': 'https://www.zalando.nl/state-of-art-overhemd-cobalt-beige-oa422d0of-k11.html',
#   'brand': 'State of Art',
#   'category': 'Overhemd',
#   'price': '79,95',
#   'delivery_time': '3--6',
#   'color': 'cobalt beige'},
#  {'url': 'https://www.zalando.nl/the-kooples-poloshirt-black-tha22p01g-q11.html',
#   'brand': 'The Kooples',
#   'category': 'Poloshirt',
#   'price': '115,00',
#   'delivery_time': '1--2',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-t-shirt-print-sand-ja222o4gc-b11.html',
#   'brand': 'Jack & Jones',
#   'category': 'T-shirt print',
#   'price': '14,99',
#   'delivery_time': '3--6',
#   'color': 'sand'},
#  {'url': 'https://www.zalando.nl/state-of-art-colour-blocks-t-shirt-print-light-greynavy-oa422o00r-c12.html',
#   'brand': 'State of Art',
#   'category': ' T-shirt print',
#   'price': '49,95',
#   'delivery_time': '3--6',
#   'color': 'light grey/navy'},
#  {'url': 'https://www.zalando.nl/henry-tiger-disney-classics-unisex-platypus-love-t-shirt-print-melange-black-h3a21026c-q11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange black'},
#  {'url': 'https://www.zalando.nl/clockhouse-overhemd-white-cfi22d004-a11.html',
#   'brand': 'CLOCKHOUSE',
#   'category': 'Overhemd',
#   'price': '15,99',
#   'delivery_time': '3--6',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/henry-tiger-disney-unisex-aurora-comic-t-shirt-print-melange-grey-h3a21026i-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jjirick-jjioriginal-jeansshort-black-denim-ja222f0te-q11.html',
#   'brand': 'Jack & Jones',
#   'category': ' Jeansshort',
#   'price': '29,99',
#   'delivery_time': '1--2',
#   'color': 'black denim'},
#  {'url': 'https://www.zalando.nl/gant-archive-shield-t-shirt-print-pistazie-ga322o02w-m13.html',
#   'brand': 'GANT',
#   'category': ' T-shirt print',
#   'price': '43,99',
#   'delivery_time': '3--6',
#   'color': 'pistazie '},
#  {'url': 'https://www.zalando.nl/origin-of-hearts-mori-kimono-shirt-overhemd-black-ors22d005-q11.html',
#   'brand': 'Origin Of Hearts',
#   'category': ' Overhemd',
#   'price': '230,00',
#   'delivery_time': '1--2',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-medium-drawstring-print-zwemshorts-multi-coloured-to182h05h-t11.html',
#   'brand': 'Tommy Hilfiger',
#   'category': ' Zwemshorts',
#   'price': '69,95',
#   'delivery_time': '1--2',
#   'color': 'multi-coloured'},
#  {'url': 'https://www.zalando.nl/state-of-art-supima-poloshirt-leafgreen-plain-oa422p04f-m11.html',
#   'brand': 'State of Art',
#   'category': ' Poloshirt',
#   'price': '79,95',
#   'delivery_time': '3--6',
#   'color': 'leafgreen plain'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a21024a-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '69,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/henry-tiger-disney-aladdin-t-shirt-print-melange-grey-h3a21022y-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/origin-of-hearts-jima-kimono-shirt-overhemd-black-ors22d006-q11.html',
#   'brand': 'Origin Of Hearts',
#   'category': ' Overhemd',
#   'price': '230,00',
#   'delivery_time': '1--2',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/lyle-and-scott-tipped-poloshirt-electric-cobaltdark-navy-ly222p039-k13.html',
#   'brand': 'Lyle & Scott',
#   'category': ' Poloshirt',
#   'price': '59,95',
#   'delivery_time': '4--8',
#   'color': 'electric cobalt/dark navy'},
#  {'url': 'https://www.zalando.nl/buratti-t-shirt-print-black-bus22o01t-q11.html',
#   'brand': 'Buratti',
#   'category': 'T-shirt print',
#   'price': '34,19',
#   'delivery_time': '1--2',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/revolution-terry-cuban-overhemd-offwhite-re622d047-a11.html',
#   'brand': 'REVOLUTION',
#   'category': ' Overhemd',
#   'price': '69,95',
#   'delivery_time': '1--2',
#   'color': 'offwhite'},
#  {'url': 'https://www.zalando.nl/national-geographic-t-shirt-basic-black-nam210002-q11.html',
#   'brand': 'National Geographic',
#   'category': 'T-shirt basic',
#   'price': '39,95',
#   'delivery_time': '4--8',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/eterna-comfort-fit-overhemd-hellblau-weiss-2et22d3w2-k11.html',
#   'brand': 'Eterna',
#   'category': ' Overhemd',
#   'price': 'Vanaf69,99',
#   'delivery_time': '3--6',
#   'color': 'hellblau weiß'},
#  {'url': 'https://www.zalando.nl/origin-of-hearts-flores-kimono-overhemd-royal-blue-ors22d007-k11.html',
#   'brand': 'Origin Of Hearts',
#   'category': ' Overhemd',
#   'price': '250,00',
#   'delivery_time': '1--2',
#   'color': 'royal blue'},
#  {'url': 'https://www.zalando.nl/massimo-dutti-short-sleeve-poloshirt-beige-m3i22p082-b11.html',
#   'brand': 'Massimo Dutti',
#   'category': ' Poloshirt',
#   'price': '39,95',
#   'delivery_time': '3--6',
#   'color': 'beige'},
#  {'url': 'https://www.zalando.nl/endless-nights-flame-unisex-overhemd-khaki-eno21002l-n11.html',
#   'brand': 'Endless Nights',
#   'category': ' Overhemd',
#   'price': '44,95',
#   'delivery_time': '1--2',
#   'color': 'khaki'},
#  {'url': 'https://www.zalando.nl/esprit-t-shirt-print-navy-es122o0ye-k11.html',
#   'brand': 'Esprit',
#   'category': ' T-shirt print',
#   'price': '25,99',
#   'delivery_time': '3--6',
#   'color': 'navy'},
#  {'url': 'https://www.zalando.nl/boss-paul-poloshirt-light-grey-bb122p0i9-c11.html',
#   'brand': 'BOSS',
#   'category': ' Poloshirt',
#   'price': '89,95',
#   'delivery_time': '1--2',
#   'color': 'light grey'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-t-shirt-print-grigio-chiaro-hr422o01h-c11.html',
#   'brand': 'Harmont & Blaine',
#   'category': ' T-shirt print',
#   'price': 'Vanaf78,00',
#   'delivery_time': '1--2',
#   'color': 'grigio chiaro'},
#  {'url': 'https://www.zalando.nl/esprit-t-shirt-print-sand-es122o0ye-b11.html',
#   'brand': 'Esprit',
#   'category': ' T-shirt print',
#   'price': '25,99',
#   'delivery_time': '3--6',
#   'color': 'sand'},
#  {'url': 'https://www.zalando.nl/henry-tiger-disney-shamrock-t-shirt-print-melange-grey-h3a210230-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a21025u-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/neil-barrett-fair-isle-thunderbolt-sweater-met-rits-cobaltsage-4ne21000h-k11.html',
#   'brand': 'Neil Barrett',
#   'category': ' Sweater',
#   'price': '320,00',
#   'delivery_time': '1--2',
#   'color': 'cobalt/sage'},
#  {'url': 'https://www.zalando.nl/endless-nights-space-unisex-longsleeve-pistachio-eno21001j-m11.html',
#   'brand': 'Endless Nights',
#   'category': ' Longsleeve',
#   'price': '39,95',
#   'delivery_time': '1--2',
#   'color': 'pistachio'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jjibowie-jjshorts-solid-shorts-oxford-tan-ja222f0px-b11.html',
#   'brand': 'Jack & Jones',
#   'category': ' Shorts',
#   'price': '39,99',
#   'delivery_time': '1--2',
#   'color': 'oxford tan'},
#  {'url': 'https://www.zalando.nl/polo-ralph-lauren-long-sleeve-sport-shirt-overhemd-bluewhite-po222d0u5-a11.html',
#   'brand': 'Polo Ralph Lauren',
#   'category': ' Overhemd',
#   'price': '119,95',
#   'delivery_time': '1--2',
#   'color': 'blue/white'},
#  {'url': 'https://www.zalando.nl/hugo-elisha-zakelijk-overhemd-navy-hu722d0lp-k12.html',
#   'brand': 'HUGO',
#   'category': ' Zakelijk overhemd',
#   'price': '89,95',
#   'delivery_time': '1--2',
#   'color': 'navy'},
#  {'url': 'https://www.zalando.nl/eterna-comfort-fit-overhemd-azurblau-2et22d3vv-k11.html',
#   'brand': 'Eterna',
#   'category': ' Overhemd',
#   'price': 'Vanaf89,99',
#   'delivery_time': '3--6',
#   'color': 'azurblau'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-overhemd-blu-screziato-hr422d06t-k12.html',
#   'brand': 'Harmont & Blaine',
#   'category': 'Overhemd',
#   'price': 'Vanaf193,00',
#   'delivery_time': '1--2',
#   'color': 'blu screziato'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-overhemd-dark-blue-hr422d06y-k11.html',
#   'brand': 'Harmont & Blaine',
#   'category': 'Overhemd',
#   'price': 'Vanaf113,00',
#   'delivery_time': '1--2',
#   'color': 'blu scuro'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-overhemd-blu-scuro-hr422d06t-k11.html',
#   'brand': 'Harmont & Blaine',
#   'category': 'Overhemd',
#   'price': 'Vanaf193,00',
#   'delivery_time': '1--2',
#   'color': 'blu scuro'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-overhemd-light-red-hr422d06y-g11.html',
#   'brand': 'Harmont & Blaine',
#   'category': 'Overhemd',
#   'price': 'Vanaf113,00',
#   'delivery_time': '1--2',
#   'color': 'rosso chiaro'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-black-h3a22o0di-q11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '69,99',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-overhemd-cognac-hr422d06t-o11.html',
#   'brand': 'Harmont & Blaine',
#   'category': 'Overhemd',
#   'price': 'Vanaf193,00',
#   'delivery_time': '1--2',
#   'color': 'cognac'},
#  {'url': 'https://www.zalando.nl/tommy-hilfiger-poloshirt-breezy-blue-to122p0a1-k19.html',
#   'brand': 'Tommy Hilfiger',
#   'category': ' Poloshirt',
#   'price': '79,95',
#   'delivery_time': '1--2',
#   'color': 'breezy blue'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-t-shirt-print-grigio-chiaro-hr422o01n-c11.html',
#   'brand': 'Harmont & Blaine',
#   'category': 'T-shirt print',
#   'price': 'Vanaf83,00',
#   'delivery_time': '1--2',
#   'color': 'grigio chiaro'},
#  {'url': 'https://www.zalando.nl/harmont-and-blaine-t-shirt-print-oliva-hr422o01n-n11.html',
#   'brand': 'Harmont & Blaine',
#   'category': 'T-shirt print',
#   'price': 'Vanaf83,00',
#   'delivery_time': '1--2',
#   'color': 'oliva'},
#  {'url': 'https://www.zalando.nl/jordan-brand-crew-t-shirt-print-plum-fog-joc22o065-i11.html',
#   'brand': 'Jordan',
#   'category': ' T-shirt print',
#   'price': '34,95',
#   'delivery_time': '1--2',
#   'color': 'plum fog'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-black-h3a21026s-q11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/eterna-langarm-slim-fit-stretch-zakelijk-overhemd-weiss-2et22d3un-a11.html',
#   'brand': 'Eterna',
#   'category': ' Zakelijk overhemd',
#   'price': 'Vanaf69,99',
#   'delivery_time': '3--6',
#   'color': 'weiß'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-black-h3a21025t-q11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/vivienne-westwood-drunken-bomber-unisex-bomberjacks-tartan-vw921000i-c11.html',
#   'brand': 'Vivienne Westwood',
#   'category': ' Bomberjacks',
#   'price': '1.105,00',
#   'delivery_time': '1--2',
#   'color': 'tartan'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-glenn-original-na-013-jeans-skinny-fit-blue-denim-ja222g1qs-k11.html',
#   'brand': 'Jack & Jones',
#   'category': ' Jeans Skinny Fit',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'blue denim'},
#  {'url': 'https://www.zalando.nl/tom-tailor-poloshirt-sky-captain-blue-white-melange-to222o14r-k12.html',
#   'brand': 'TOM TAILOR',
#   'category': 'Poloshirt',
#   'price': '25,99',
#   'delivery_time': '3--6',
#   'color': 'sky captain blue white melange'},
#  {'url': 'https://www.zalando.nl/neil-barrett-fair-isle-thunderbolt-sweater-met-rits-naturaldark-beige-4ne21000h-a11.html',
#   'brand': 'Neil Barrett',
#   'category': ' Sweater',
#   'price': '320,00',
#   'delivery_time': '1--2',
#   'color': 'natural/dark beige'},
#  {'url': 'https://www.zalando.nl/massimo-dutti-overhemd-dark-blue-m3i22d0q3-k11.html',
#   'brand': 'Massimo Dutti',
#   'category': ' Overhemd',
#   'price': '59,95',
#   'delivery_time': '3--6',
#   'color': 'dark blue'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a21025n-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-melange-grey-h3a210246-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '69,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-white-h3a21025m-a11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'white'},
#  {'url': 'https://www.zalando.nl/pullandbear-oversized-sweater-beige-puc21j0tn-b11.html',
#   'brand': 'PULL&BEAR',
#   'category': ' Hoodie',
#   'price': '19,99',
#   'delivery_time': '4--8',
#   'color': 'beige'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jprblacardiff-shirt-zakelijk-overhemd-black-ja222d253-q11.html',
#   'brand': 'Jack & Jones',
#   'category': ' Zakelijk overhemd',
#   'price': '39,99',
#   'delivery_time': '1--4',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/young-poets-society-aris-broek-vintage-black-yoj22e00f-q11.html',
#   'brand': 'YOUNG POETS SOCIETY',
#   'category': ' Broek',
#   'price': '99,95',
#   'delivery_time': '1--2',
#   'color': 'vintage black'},
#  {'url': 'https://www.zalando.nl/boggi-milano-overhemd-green-bq122d020-m11.html',
#   'brand': 'Boggi Milano',
#   'category': ' Overhemd',
#   'price': '79,00',
#   'delivery_time': '1--2',
#   'color': 'green'},
#  {'url': 'https://www.zalando.nl/camel-active-kurzarm-aus-t-shirt-basic-green-ca522o04e-m11.html',
#   'brand': 'camel active',
#   'category': ' T-shirt basic',
#   'price': 'Vanaf29,95',
#   'delivery_time': '3--6',
#   'color': 'green'},
#  {'url': 'https://www.zalando.nl/state-of-art-overhemd-cobalt-white-oa422d0og-k11.html',
#   'brand': 'State of Art',
#   'category': 'Overhemd',
#   'price': '79,95',
#   'delivery_time': '3--6',
#   'color': 'cobalt white'},
#  {'url': 'https://www.zalando.nl/brave-soul-t-shirt-print-optic-whitejet-black-brh22o0bw-a11.html',
#   'brand': 'Brave Soul',
#   'category': 'T-shirt print',
#   'price': '17,95',
#   'delivery_time': '4--8',
#   'color': 'optic white/jet black'},
#  {'url': 'https://www.zalando.nl/ellesse-t-shirt-print-gruen-el922o0df-m11.html',
#   'brand': 'Ellesse',
#   'category': ' T-shirt print',
#   'price': '33,95',
#   'delivery_time': '3--6',
#   'color': 'grün'},
#  {'url': 'https://www.zalando.nl/boggi-milano-overhemd-light-blu-bq122d01y-k11.html',
#   'brand': 'Boggi Milano',
#   'category': 'Overhemd',
#   'price': '99,00',
#   'delivery_time': '1--2',
#   'color': 'light blu'},
#  {'url': 'https://www.zalando.nl/henry-tiger-disney-classics-unisex-no-rules-t-shirt-print-melange-grey-h3a21026j-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/henry-tiger-marvel-unisex-home-couple-t-shirt-print-black-h3a22o0d0-q11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/henry-tiger-disney-classics-rebel-heart-t-shirt-print-melange-grey-h3a210229-c11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange grey'},
#  {'url': 'https://www.zalando.nl/kinetix-basic-c-neck-t-shirt-basic-grey-mel-kiw22o002-c11.html',
#   'brand': 'kinetix',
#   'category': ' T-shirt basic',
#   'price': '19,95',
#   'delivery_time': '1--2',
#   'color': 'grey mel'},
#  {'url': 'https://www.zalando.nl/anerkjendt-akkian-block-overhemd-tofu-a2322d05y-a11.html',
#   'brand': 'Anerkjendt',
#   'category': ' Overhemd',
#   'price': '59,95',
#   'delivery_time': '1--2',
#   'color': 'tofu'},
#  {'url': 'https://www.zalando.nl/pier-one-overhemd-black-pi922d0co-q11.html',
#   'brand': 'Pier One',
#   'category': 'Overhemd',
#   'price': '24,99',
#   'delivery_time': '1--2',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-melange-black-h3a21025z-q11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange black'},
#  {'url': 'https://www.zalando.nl/jack-and-jones-jorollie-solid-overhemd-black-ja222d211-q11.html',
#   'brand': 'Jack & Jones',
#   'category': ' Overhemd',
#   'price': '39,99',
#   'delivery_time': '1--2',
#   'color': 'black'},
#  {'url': 'https://www.zalando.nl/michael-kors-overhemd-chambray-1mi22d06y-k11.html',
#   'brand': 'Michael Kors',
#   'category': 'Overhemd',
#   'price': '109,95',
#   'delivery_time': '1--2',
#   'color': 'chambray'},
#  {'url': 'https://www.zalando.nl/henry-tiger-t-shirt-print-melange-black-h3a21025y-q11.html',
#   'brand': 'Henry Tiger',
#   'category': ' T-shirt print',
#   'price': '29,99',
#   'delivery_time': '3--6',
#   'color': 'melange black'}]

# %% [markdown]
# ### 2.6 Write collected information to a CSV file

# %%
with open("product_description_herenkleding.csv", "w", encoding = 'utf-8', newline='') as csv_file: 
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(["url", "brand", "category", "price", "delivery_time", "color", "date"])
    now = datetime.now()
    for product in product_attributes: 
        writer.writerow([product['url'], product['brand'], product['category'], product['price'], product['delivery_time'], product['color'], now])
print('done!')
# Out:
# done!

# %% [markdown]
# ## Chapter 3: Data inspection
# The results of both web scrapers is saved in separate CSV files. For each dataset data inspection is executed using RStudio. Also, both dataset are cleaned so that they can be used to determine similarities and differences between the different clothing sections.
